# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from keras import layers
from tensorflow.keras import Model
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.applications.vgg16 import VGG16
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#read the image
# function to load the dataset and return the dataset list
# containing elements of format [scans, target]
targets = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(scans):
    data = list()
    for target in targets: 
        path = os.path.join(scans, target)
        class_label = targets.index(target)
        for img in os.listdir(path):
            try:
                arr = cv2.imread(os.path.join(path, img))
                resized_arr = cv2.resize(arr, (img_size, img_size))
                data.append([resized_arr, class_label])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
#extracting the dataset
train = get_training_data('/content/gdrive/MyDrive/PythonProjectWebApp/chest_xray/train')
test = get_training_data('/content/gdrive/MyDrive/PythonProjectWebApp/chest_xray/test')
val = get_training_data('/content/gdrive/MyDrive/PythonProjectWebApp/chest_xray/val')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
#split the data into training, testing and validation groups with variables to hold the target names.
images = []
labels = []

for image_scan, target in train:
    images.append(image_scan)
    labels.append(target)

for image_scan, target in test:
    images.append(image_scan)
    labels.append(target)

for image_scan, target in val:
    images.append(image_scan)
    labels.append(target)

# %%
# Normalize data
images = np.array(images) / 255

# %%
# resize data
images = images.reshape(-1, img_size, img_size, 3)
labels = np.array(labels)

# %%
#prevents overfitting and handles the imbalance in dataset

data_aug = ImageDataGenerator(
        rotation_range = 30,  #rotate 
        zoom_range = 0.2, #  zoom  
        width_shift_range=0.1,  #  shift images horizontally 
        height_shift_range=0.1,  #  shift images vertically
        horizontal_flip = True,  # flip images
        vertical_flip=False)  # no vertical flip

data_aug.fit(images)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=.30, shuffle=True)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=.30, shuffle=True)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (4099, 150, 150, 3)
# (1229, 150, 150, 3)
# (528, 150, 150, 3)

# %%
print(X_train.shape[1:])
# Out:
# (150, 150, 3)

# %%
#building the model
IMAGE_SIZE = X_train.shape[1:]

vgg = VGG16(input_shape=IMAGE_SIZE, weights='imagenet', include_top=False)

# freezing restNet layers
for layer in vgg.layers:
  layer.trainable = False

x = Flatten()(vgg.output)

output_layer = Dense(1, activation='sigmoid')(x)

# creating early stopping.
es = EarlyStopping(monitor='val_loss', mode='min', patience = 5, restore_best_weights=True)
# creating model checkpoint
mc = ModelCheckpoint("VggModel.h5", monitor='val_loss', mode='min', verbose=1, save_best_only=True)
# creating class weights
#cw = {0: 1.0, 1: 1.0}

model = Model(inputs=vgg.input, outputs=output_layer)

model.summary()

plot_model(model, to_file = 'modelVgg_plot.png', show_shapes = True, show_layer_names = True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_1 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 14,722,881
# Trainable params: 8,193
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# fitting the model
history = model.fit(X_train, y_train, batch_size = 128, epochs=12, validation_data=(X_test, y_test), callbacks = [es,mc],verbose=1)#,class_weight=cw)
# Out:
# Epoch 1/12
# 33/33 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.8595
# Epoch 1: val_loss improved from inf to 0.20910, saving model to VggModel.h5
# 33/33 [==============================] - 31s 891ms/step - loss: 0.3379 - accuracy: 0.8595 - val_loss: 0.2091 - val_accuracy: 0.9268
# Epoch 2/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9397
# Epoch 2: val_loss improved from 0.20910 to 0.16664, saving model to VggModel.h5
# 33/33 [==============================] - 28s 853ms/step - loss: 0.1811 - accuracy: 0.9397 - val_loss: 0.1666 - val_accuracy: 0.9398
# Epoch 3/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9490
# Epoch 3: val_loss improved from 0.16664 to 0.15642, saving model to VggModel.h5
# 33/33 [==============================] - 28s 852ms/step - loss: 0.1502 - accuracy: 0.9490 - val_loss: 0.1564 - val_accuracy: 0.9439
# Epoch 4/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9551
# Epoch 4: val_loss improved from 0.15642 to 0.14083, saving model to VggModel.h5
# 33/33 [==============================] - 28s 852ms/step - loss: 0.1341 - accuracy: 0.9551 - val_loss: 0.1408 - val_accuracy: 0.9496
# Epoch 5/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9605
# Epoch 5: val_loss improved from 0.14083 to 0.13356, saving model to VggModel.h5
# 33/33 [==============================] - 28s 854ms/step - loss: 0.1229 - accuracy: 0.9605 - val_loss: 0.1336 - val_accuracy: 0.9504
# Epoch 6/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9636
# Epoch 6: val_loss improved from 0.13356 to 0.13316, saving model to VggModel.h5
# 33/33 [==============================] - 28s 851ms/step - loss: 0.1159 - accuracy: 0.9636 - val_loss: 0.1332 - val_accuracy: 0.9528
# Epoch 7/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9619
# Epoch 7: val_loss improved from 0.13316 to 0.12510, saving model to VggModel.h5
# 33/33 [==============================] - 28s 852ms/step - loss: 0.1111 - accuracy: 0.9619 - val_loss: 0.1251 - val_accuracy: 0.9544
# Epoch 8/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9658
# Epoch 8: val_loss improved from 0.12510 to 0.12191, saving model to VggModel.h5
# 33/33 [==============================] - 28s 853ms/step - loss: 0.1044 - accuracy: 0.9658 - val_loss: 0.1219 - val_accuracy: 0.9577
# Epoch 9/12
# 33/33 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9658
# Epoch 9: val_loss did not improve from 0.12191
# 33/33 [==============================] - 28s 846ms/step - loss: 0.1011 - accuracy: 0.9658 - val_loss: 0.1231 - val_accuracy: 0.9561
# Epoch 10/12
# 33/33 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9678
# Epoch 10: val_loss improved from 0.12191 to 0.12007, saving model to VggModel.h5
# 33/33 [==============================] - 28s 853ms/step - loss: 0.0963 - accuracy: 0.9678 - val_loss: 0.1201 - val_accuracy: 0.9536
# Epoch 11/12
# 33/33 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9693
# Epoch 11: val_loss improved from 0.12007 to 0.11668, saving model to VggModel.h5
# 33/33 [==============================] - 28s 852ms/step - loss: 0.0910 - accuracy: 0.9693 - val_loss: 0.1167 - val_accuracy: 0.9544
# Epoch 12/12
# 33/33 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9734
# Epoch 12: val_loss did not improve from 0.11668
# 33/33 [==============================] - 28s 844ms/step - loss: 0.0879 - accuracy: 0.9734 - val_loss: 0.1371 - val_accuracy: 0.9430

# %%
model.save('PNmodelVgg.h5')

# %%
model.evaluate(X_val,y_val)
# Out:
# 17/17 [==============================] - 3s 195ms/step - loss: 0.1238 - accuracy: 0.9527
# [0.12381497025489807, 0.9526515007019043]

# %%
#plotting the data to demonstrate the accuracy of the train and validations. 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'val'])
plt.show()

#plotting the data to demonstrate the loss of the train and validations. 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
